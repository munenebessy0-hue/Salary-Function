# %%
import os
import zipfile
import pandas as pd

# Import salary data
try:
    salary_data = pd.read_csv(r"C:\Users\User\Documents\Total.csv")
    display(salary_data.head())
except FileNotFoundError:
    print("Error: salary_data.csv not found.")

def get_employee_details(name, df):
    """
    Retrieve employee details from the DataFrame by employee name.
    """
    try:
        employee = df[df['EmployeeName'].str.lower() == name.lower()]
        if employee.empty:
            raise ValueError(f"No employee found with name: {name}")
        return employee
    except Exception as e:
        print("Error retrieving employee:", e)
        return None

# Example
print(get_employee_details("NATHANIEL FORD", salary_data))

# Convert salary data into a dictionary
try:
    salary_dict = salary_data.to_dict(orient="records")  # list of dictionaries
    print("Sample dictionary entry:\n", salary_dict[0])
except Exception as e:
    print("Error converting DataFrame to dictionary:", e)


def export_employee(name, df):
    """
    Export employee details to a CSV file and zip the folder.
    """
    emp = get_employee_details(name, df)
    
    if emp is None:  # if retrieval failed
        return
    
    # Ensure output folder exists
    folder_name = "Employee Profile"
    os.makedirs(folder_name, exist_ok=True)

    # Save employee details to CSV
    file_path = os.path.join(folder_name, f"{name}_details.csv")
    emp.to_csv(file_path, index=False)

    # Zip the folder
    zip_file = f"{folder_name}.zip"
    with zipfile.ZipFile(zip_file, 'w') as zipf:
        for root, _, files in os.walk(folder_name):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, folder_name)
                zipf.write(file_path, arcname=arcname)

    print(f"Employee details exported and zipped as {zip_file}")


# Example
export_employee("NATHANIEL FORD", salary_data)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9020\3398375081.py:7: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   salary_data = pd.read_csv(r"C:\Users\User\Documents\Total.csv")
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay      Benefits   TotalPay  \
# 0  167411.18         0.0  400184.25  Not Provided  567595.43
# 1  155966.02   245131.88  137811.38  Not Provided  538909.28
# 2  212739.13   106088.18    16452.6  Not Provided  335279.91
# 3    77916.0    56120.71   198306.9  Not Provided  332343.61
# 4   134401.6      9737.0  182234.59  Not Provided  326373.19
#
#    TotalPayBenefits  Year
# 0         567595.43  2011
# 1         538909.28  2011
# 2         335279.91  2011
# 3         332343.61  2011
# 4         326373.19  2011
#      EmployeeName                                        JobTitle    BasePay  \
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
#
#   OvertimePay   OtherPay      Benefits   TotalPay  TotalPayBenefits  Year
# 0         0.0  400184.25  Not Provided  567595.43         567595.43  2011
# Sample dictionary entry:
#  {'EmployeeName': 'NATHANIEL FORD', 'JobTitle': 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 'BasePay': 167411.18, 'OvertimePay': 0.0, 'OtherPay': 400184.25, 'Benefits': 'Not Provided', 'TotalPay': 567595.43, 'TotalPayBenefits': 567595.43, 'Year': 2011}
# Employee details exported and zipped as Employee Profile.zip
# c:\Users\User\Documents
# ['.RData', '.Rhistory', '06-05-2025_22-50-31_A009680988P_ITR.zip', '06-05-2025_22-53-01_A009680988P_ITR.zip', '06-05-2025_23-48-27_A009680988P_ITR.zip', '151-200', '1st-31st May.docx', '1st-7th May.docx', '200-250', '201-250', '203 Technical Questionnaire.pdf', '223 technical questionnaire.pdf', '251-300', '28-06-2024_20-29-05_A009680988P_ITR.zip', '28-06-2024_20-30-27_A009680988P_ITR.zip', '3rd-6th swahili devotions.docx', '4th-8th June.docx', '501-550', '551-600', '9th-16th.docx', '9th-30th June.docx', 'Abandon status.docx', 'Adjusted.docx', 'Adobe', 'AJIRA PROGRAM.docx', 'Analysis.docx', 'Answers.docx', 'Answers1.docx', 'Answers2.docx', 'Answers3.docx', 'APPEN.docx', 'Appraisal.docx', 'Assignment.docx', 'Audacity', 'B.MAKENA coverletter GRADUATE.docx', 'Background checks consent - October 2021.pdf', 'Bessy Makena cv.docx', 'BESSY MUSES.docx', 'Best practices for bidding on Upwork.docx', 'Book1.xlsm', 'Book1.xlsx', 'BUDGET EXCEL.xlsx', 'Budget PCEA.docx', 'CAREER DECISIONS.xlsx', 'certificate.pdf', 'CHALLENGES FACED BY THE EARLY CHURCH AND REMEDIES EMPLOYED.docx', 'Christine Atieno.txt', 'chrome-win', 'CIVILIZATION.docx', 'client.xlsx', 'Copy of ASSESSEMENT 3 BIOSTATISTICS SPSS.xlsx', 'Custom Office Templates', 'CV WORKING PROGRESS.docx', 'desktop.ini', 'Discuss methods of building your brand on social media platforms.docx', 'Doc1.docx', 'draft.docx', 'Employee Profile', 'Employee Profile.zip', 'Explain the concept of networking as used in online working.docx', 'F.pdf', 'GAKII CV.docx', 'GAKII_CV.docx', 'Gakii_Linet_cover letter -1.docx', 'Gakii_Linet_cover letter.docx', 'GAKII_LINET_CV.docx', 'Gakii_Linet_Internship Application.zip', 'Gakii_Linet_Munene Cover letter.docx', 'Gakii_Munene CV.docx', 'Gakii_Munene_cover letter.docx', 'GAKII_MUNENE_CV.docx', 'GAKII_MUNENE_CV.pdf', 'Gakii_Munene_Linet CV.docx', 'GAYAZA IS INVITING YOU FOR.docx', 'Gazzetment.pdf', 'GRADE BOOK.xlsx', 'Graduating with my Bachelor.docx', 'HARD AND SOFT SKILLS REQUIRED BY AN ONLINE WORKER.docx', 'Highly resourceful.docx', 'Highridge Payments.zip', 'hotel_bookings.xlsx', 'Imports from South Africa from ICS- Faith.xlsx', 'Imports Vietnam Cambodia Laos and Myanmar from ICS- Faith.xlsx', 'INQUIRIES.docx', 'INSTRUCTIONS TRANSCRIBING.docx', 'KingsoftData', 'kiptoo codes.R', 'kiptoo codes.txt', 'kiptoo final codes.txt', 'Kiptoo software output.docx', 'Kiptoo.docx', 'Kiptoo.docx.xlsx', 'Kiptoo_corrected version.docx', 'LETTER TO MY DAUGHTER.docx', 'LINET GAKII MUNEN1.docx', 'LINET GAKII MUNEN2.docx', 'LINET GAKII MUNENE APPLICATION.docx', 'LINET GAKII MUNENE APPLICATION.pdf', 'Linet Gakii Munene Letter.docx', 'LINET GAKII MUNENE.docx', 'LINET GAKII MUNENE.pdf', 'Linet Human Resource Intern Cover Letter.pdf', 'Linet Munene Cover letter.pdf', 'LINET_ GAKII_ INTERNSHIP COVER LETTER.docx', 'Linet_Gakii_Resume.docx', 'Linet_Gakii_Resume.pdf', 'LINET_MUNENE_CV.pdf', 'Linet_Munene_Gakii CV.docx', 'linked profile-christine.docx', 'MANAGEMENT TRAINEE.docx', 'Manifest Kenya 4 list.xlsx', "Marrieds' Conference", 'Math.docx', 'multiple_choice_cleanup.xlsx', 'MUNENE_GAKII_CV.docx', 'MUNENE_GAKII_CV.pdf', 'MUNENE_GAKII_LINET_CV.docx', 'Munene_Linet_cover letter.docx', 'Munene_Linet_CV.docx', 'Munene_Linet_Gakii-cover letter.docx', 'Mutwiri.docx', 'My Data.xlsm', 'My Data.xlsx', 'My Music', 'My Pictures', 'My Videos', 'My_Responsibility.xlsx', 'newemployees.csv', 'November week two 2021-imports and exports.xlsx', 'Objective.docx', 'Overall.docx', 'Part2.xlsx', 'payroll.py', 'payroll.R', 'PAYROLL.xlsx', 'PCEA LANGATA YOUTH BUDGET.docx', 'Peoples.docx', 'Phaneroo sermon notes', 'Phaneroo Sermons.xlsx', 'PHANEROO.docx', 'pip3 install notebook.py', 'PIVOT TABLE.xlsx', 'R', 'raw results.xlsx', 'README.txt', 'REFEREES.docx', 'REFEREES.pdf', 'Response A.docx', 'Results-website.docx', 'Rosemary Ndambuki Recommendation Letter.docx', 'salary_data.ipynb', 'salary_unzip.r', 'Selling yourself effectively.docx', 'Skills Required by an Online writer.docx', 'SOFT SKILLS.docx', 'STAT ANALYS ...
